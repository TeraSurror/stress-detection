# %%
import pandas as pd
import numpy as np

# %%
sleep_data = pd.read_csv('~/Projects/stress-detection/backend/dataset/cleaned-dataset.csv')
sleep_data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#    Heart Rate  Daily Steps Sleep Disorder  BP High  BP Low
# 0          77         4200    No Disorder      126      83
# ...

# %%
sleep_duration = sleep_data['Sleep Duration']
sleep_duration.head()
# Out:
# 0    6.1
# 1    6.2
# 2    6.2
# 3    5.9
# 4    5.9
# Name: Sleep Duration, dtype: float64

# %%
for column in sleep_data.columns:
    sleep_col_data = sleep_data[column]
    sleep_col_data.to_json(f"{column.lower().replace(' ', '_')}.json")
